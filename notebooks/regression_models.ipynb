# %%
import pandas as pd

flights = pd.read_csv("../data/cleaned/cleaned_flights.csv")

# %%
flights["carrier_code"].value_counts()
# Out:
# carrier_code
# UA    110738
# DL     68152
# AA     58625
# AS     34235
# B6     15636
# Name: count, dtype: int64

# %%
import statsmodels.formula.api as smf

model = smf.ols("departure_delay_minutes ~ departure_hour", data=flights).fit()

print(model.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     departure_delay_minutes   R-squared:                       0.001
# Model:                                 OLS   Adj. R-squared:                  0.001
# Method:                      Least Squares   F-statistic:                     209.5
# Date:                     Thu, 28 May 2026   Prob (F-statistic):           1.79e-47
# Time:                             16:17:00   Log-Likelihood:            -1.5568e+06
# No. Observations:                   287386   AIC:                         3.114e+06
# Df Residuals:                       287384   BIC:                         3.114e+06
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          6.8594      0.264     25.979      0.000       6.342       7.377
# departure_hour     0.2700      0.019     14.476      0.000       0.233       0.307
# ==============================================================================
# Omnibus:                   493669.247   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        784748234.399
# Skew:                          11.858   Prob(JB):                         0.00
# Kurtosis:                     257.898   Cond. No.                         36.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Departure hour was a statistically significant predictor of departure delay ($p < 0.001$), with delays increasing by 0.27 minutes for each additional hour later in the day. However, the model explained very little of the overall variation in delays ($R^2 = 0.001$), suggesting that departure hour alone is not a strong predictor of delay length.

# %%
model2 = smf.ols("departure_delay_minutes ~ departure_hour + C(carrier_code) + C(day_of_week) + C(month) + C(origin_airport)",
data=flights).fit()

print(model2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     departure_delay_minutes   R-squared:                       0.008
# Model:                                 OLS   Adj. R-squared:                  0.008
# Method:                      Least Squares   F-statistic:                     96.86
# Date:                     Thu, 28 May 2026   Prob (F-statistic):               0.00
# Time:                             16:35:12   Log-Likelihood:            -1.5557e+06
# No. Observations:                   287386   AIC:                         3.111e+06
# Df Residuals:                       287361   BIC:                         3.112e+06
# Df Model:                               24
# Covariance Type:                 nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      12.6846      0.483     26.242      0.000      11.737      13.632
# C(carrier_code)[T.AS]          -8.4292      0.377    -22.372      0.000      -9.168      -7.691
# C(carrier_code)[T.B6]          -4.7056      0.490     -9.601      0.000      -5.666      -3.745
# C(carrier_code)[T.DL]          -6.9661      0.306    -22.759      0.000      -7.566      -6.366
# C(carrier_code)[T.UA]          -9.2630      0.290    -31.908      0.000      -9.832      -8.694
# C(day_of_week)[T.Monday]       -0.2797      0.373     -0.750      0.453      -1.010       0.451
# C(day_of_week)[T.Saturday]     -1.8004      0.383     -4.696      0.000      -2.552      -1.049
# C(day_of_week)[T.Sunday]        2.3646      0.373      6.343      0.000       1.634       3.095
# C(day_of_week)[T.Thursday]      0.8797      0.371      2.370      0.018       0.152       1.607
# C(day_of_week)[T.Tuesday]      -3.9803      0.381    -10.458      0.000      -4.726      -3.234
# C(day_of_week)[T.Wednesday]    -2.4743      0.377     -6.568      0.000      -3.213      -1.736
# C(month)[T.2]                   0.3749      0.401      0.936      0.349      -0.410       1.160
# C(month)[T.3]                  -1.5748      0.472     -3.337      0.001      -2.500      -0.650
# C(month)[T.4]                  -3.1551      0.471     -6.700      0.000      -4.078      -2.232
# C(month)[T.5]                   0.4927      0.459      1.074      0.283      -0.406       1.392
# C(month)[T.6]                   1.8519      0.459      4.033      0.000       0.952       2.752
# C(month)[T.7]                   5.8144      0.454     12.811      0.000       4.925       6.704
# C(month)[T.8]                   1.2386      0.459      2.699      0.007       0.339       2.138
# C(month)[T.9]                  -3.1160      0.471     -6.613      0.000      -4.040      -2.192
# C(month)[T.10]                 -0.4414      0.459     -0.961      0.336      -1.342       0.459
# C(month)[T.11]                  0.8908      0.469      1.900      0.057      -0.028       1.810
# C(month)[T.12]                  4.9723      0.466     10.680      0.000       4.060       5.885
# C(origin_airport)[T.SAN]        0.6411      0.298      2.154      0.031       0.058       1.224
# C(origin_airport)[T.SFO]        0.6827      0.238      2.873      0.004       0.217       1.148
# departure_hour                  0.2966      0.019     15.890      0.000       0.260       0.333
# ==============================================================================
# Omnibus:                   492982.538   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        781416384.829
# Skew:                          11.822   Prob(JB):                         0.00
# Kurtosis:                     257.358   Cond. No.                         144.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(model2.params)
# Out:
# Intercept                      12.684553
# C(carrier_code)[T.AS]          -8.429221
# C(carrier_code)[T.B6]          -4.705579
# C(carrier_code)[T.DL]          -6.966073
# C(carrier_code)[T.UA]          -9.262983
# C(day_of_week)[T.Monday]       -0.279661
# C(day_of_week)[T.Saturday]     -1.800415
# C(day_of_week)[T.Sunday]        2.364639
# C(day_of_week)[T.Thursday]      0.879710
# C(day_of_week)[T.Tuesday]      -3.980263
# C(day_of_week)[T.Wednesday]    -2.474250
# C(month)[T.2]                   0.374897
# C(month)[T.3]                  -1.574833
# C(month)[T.4]                  -3.155057
# C(month)[T.5]                   0.492730
# C(month)[T.6]                   1.851883
# C(month)[T.7]                   5.814414
# C(month)[T.8]                   1.238616
# C(month)[T.9]                  -3.116005
# C(month)[T.10]                 -0.441425
# C(month)[T.11]                  0.890833
# C(month)[T.12]                  4.972270
# C(origin_airport)[T.SAN]        0.641107
# C(origin_airport)[T.SFO]        0.682683
# departure_hour                  0.296554
# dtype: float64

# %% [markdown]
# A multiple linear regression model was fit using departure delay by minutes as the response variable and departure hour, airline, day of week, month, and origin airport as predictors. American Airlines (AA), Friday, January, and LAX were used as the reference categories.
#
# The model was statistically significant (p < 0.001), but the $R^2$ value remained low at 0.08, indicating that these variables explain only a small portion of the overall variation in departure delays.
#
# Relative to American Airlines, Alaska, JetBlue, Delta, and United all had lower average departure delays after controlling for the other variables. Tuesday and Wednesday flights tended to have lower delays than Friday flights, while Sunday flights tended to have higher delays. Seasonal effects were also observed, with July and December showing higher average delays. Also, flights departing from SAN and SFO experienced slightly higher average delays than flights departing from LAX.
#
# The results suggest that airline, departure time, day of week, season, and airport are all associated with departure delays, although additional factors likely account for most of the variation.
